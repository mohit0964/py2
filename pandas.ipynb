# %%
import pandas as pd
import numpy as np

# %%
FUNCTIONS:
    
head      = bydefault it gives us first 5 observation (12)
tail      = bydefault it gives us last 5 observation (12)
info      = rageindex :    ,data colume (no.columns),null values and data type,memeory allocation
size      = multiplication of rows and col 
shape     = colu and rows value out put in tuple data type
describe  = it gives us numerical values mean,meadian,sd,max min,25%,75%,50%,
isnull.sum()   = exact count of null value
isnull() = it gives boolean value true for the null value ,false for the regular value
isna    =both are same
fillna  = it fills all the null values by anything
columns  = name of cloumns and length of colm
index    =(sart ,stop,step)
axes      =it the combinations index and columns 
loc       =it will the access the rows and columns 
iloc      =it will the access the rows and columns by indexing or we can access the single elemnet from the ilco
sort_index = it sort the index  axis= 0 rows ,axis =1 columns
set_index  = for replacing the index 
reset_index = original indexing 
sort_values = for sorting pericular col
df.T       =it convert row to col and col to row


PARAMETERS:
inplace =True   == if we want to store the changes in the dataframe 
axis =0 >> Rows
     =1 >> Columns
ascending 
index
columns

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Emp_Records  (1).csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02            NaN             NaN   51063
# 2  428945        Joe       54.15           68.0            0.98   50155
# 3  408351      Diane       39.67            NaN           18.30  180294
# 4  193819   Benjamin       40.31           58.0            4.01  117642
#
#            City
# 0           NaN
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
df.tail()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 95        Biloxi
# 96  Carol Stream
# 97       Detroit
# 98      Mc Grath
# 99          Alma

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      100 non-null    float64
#  3   Weight in Kgs   97 non-null     float64
#  4   Age in Company  99 non-null     float64
#  5   Salary          100 non-null    int64
#  6   City            99 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
df.shape
# Out:
# (100, 7)

# %%
df.size
# Out:
# 700

# %% [markdown]
# isnull :- to find the null values in the dataframe
# isna :- isnull and isna are same
# isnull().sum()  :- it gives the sum pf null values in the dataframe
# isna().sum() :- it is same as isnull().sum()

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.isnull()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False           True           False   False
# 1    False       False       False           True            True   False
# 2    False       False       False          False           False   False
# 3    False       False       False           True           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0    True
# 1   False
# 2   False
# 3   False
# 4   False
# ...

# %%
df.isnull().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     3
# Age in Company    1
# Salary            0
# City              1
# dtype: int64

# %%
df.isna().sum()
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     3
# Age in Company    1
# Salary            0
# City              1
# dtype: int64

# %%
df

# %%
df.isna()
# Out:
#     Emp ID  First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0    False       False       False           True           False   False
# 1    False       False       False           True            True   False
# 2    False       False       False          False           False   False
# 3    False       False       False           True           False   False
# 4    False       False       False          False           False   False
# ..     ...         ...         ...            ...             ...     ...
# 95   False       False       False          False           False   False
# 96   False       False       False          False           False   False
# 97   False       False       False          False           False   False
# 98   False       False       False          False           False   False
# 99   False       False       False          False           False   False
#
#      City
# 0    True
# 1   False
# 2   False
# 3   False
# 4   False
# ...

# %%
df.describe()
# Out:
#              Emp ID  Age in Yrs  Weight in Kgs  Age in Company         Salary
# count     100.00000  100.000000      97.000000       99.000000     100.000000
# mean   547652.10000   39.238700      58.113402        8.978081  119738.090000
# std    257664.16679   12.066252      12.460668        8.701416   46185.278194
# min    134841.00000   21.100000      40.000000        0.020000   42005.000000
# 25%    328643.75000   28.177500      50.000000        2.045000   83979.750000
# 50%    497414.00000   37.595000      56.000000        5.930000  118049.500000
# 75%    766040.00000   49.900000      62.000000       13.845000  162509.250000
# max    979607.00000   59.470000      90.000000       34.520000  197537.000000

# %%
df['Salary'].min()
# Out:
# 42005

# %%
df['Salary'].max()
# Out:
# 197537

# %%
df["Salary"].mean()
# Out:
# 119738.09

# %%
df.head(1)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary City
# 0  677509       Lois       36.36            NaN           13.68  168251  NaN

# %% [markdown]
# # fillna = used to fill the null values

# %%
df1 = df.fillna(df.mean())
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df1 = df.fillna(df.mean())
#       2 df1
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:11335, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11327 @doc(make_doc("mean", ndim=2))
#   11328 def mean(
#   11329     self,
#    (...)
#   11333     **kwargs,
#   11334 ):
# > 11335     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11336     if isinstance(result, Series):
#   11337         result = result.__finalize__(self, method="mean")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# ...

# %%
df["Weight in Kgs"].mean()
# Out:
# 58.11340206185567

# %%
df.fillna(df["Weight in Kgs"].mean())
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36      58.113402       13.680000  168251
# 1   940761     Brenda       47.02      58.113402       58.113402   51063
# 2   428945        Joe       54.15      68.000000        0.980000   50155
# 3   408351      Diane       39.67      58.113402       18.300000  180294
# 4   193819   Benjamin       40.31      58.000000        4.010000  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82      89.000000        1.050000  129774
# 96  704709     Harold       32.61      77.000000        5.930000  156194
# 97  461593     Nicole       52.66      60.000000       28.530000   95673
# 98  392491    Theresa       29.60      57.000000        6.990000   51015
# 99  495141      Tammy       38.38      55.000000        2.260000   93650
#
#             City
# 0      58.113402
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.fillna("Stonewall")
# Out:
#     Emp ID First Name  Age in Yrs Weight in Kgs Age in Company  Salary  \
# 0   677509       Lois       36.36     Stonewall          13.68  168251
# 1   940761     Brenda       47.02     Stonewall      Stonewall   51063
# 2   428945        Joe       54.15          68.0           0.98   50155
# 3   408351      Diane       39.67     Stonewall           18.3  180294
# 4   193819   Benjamin       40.31          58.0           4.01  117642
# ..     ...        ...         ...           ...            ...     ...
# 95  639892       Jose       22.82          89.0           1.05  129774
# 96  704709     Harold       32.61          77.0           5.93  156194
# 97  461593     Nicole       52.66          60.0          28.53   95673
# 98  392491    Theresa       29.60          57.0           6.99   51015
# 99  495141      Tammy       38.38          55.0           2.26   93650
#
#             City
# 0      Stonewall
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# 4        Fremont
# ...

# %%
df1 = df["Weight in Kgs"].fillna(value = df["Weight in Kgs"].mean(),inplace = True)
df1

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36      58.113402           13.68  168251
# 1   940761     Brenda       47.02      58.113402             NaN   51063
# 2   428945        Joe       54.15      68.000000            0.98   50155
# 3   408351      Diane       39.67      58.113402           18.30  180294
# 4   193819   Benjamin       40.31      58.000000            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82      89.000000            1.05  129774
# 96  704709     Harold       32.61      77.000000            5.93  156194
# 97  461593     Nicole       52.66      60.000000           28.53   95673
# 98  392491    Theresa       29.60      57.000000            6.99   51015
# 99  495141      Tammy       38.38      55.000000            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df["Age in Company"].mean()
# Out:
# 8.978080808080806

# %%
df["Age in Company"].fillna(value = df["Age in Company"].mean(),inplace = True)

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36      58.113402       13.680000  168251
# 1   940761     Brenda       47.02      58.113402        8.978081   51063
# 2   428945        Joe       54.15      68.000000        0.980000   50155
# 3   408351      Diane       39.67      58.113402       18.300000  180294
# 4   193819   Benjamin       40.31      58.000000        4.010000  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82      89.000000        1.050000  129774
# 96  704709     Harold       32.61      77.000000        5.930000  156194
# 97  461593     Nicole       52.66      60.000000       28.530000   95673
# 98  392491    Theresa       29.60      57.000000        6.990000   51015
# 99  495141      Tammy       38.38      55.000000        2.260000   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.head(2)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36      58.113402       13.680000  168251
# 1  940761     Brenda       47.02      58.113402        8.978081   51063
#
#         City
# 0        NaN
# 1  Stonewall

# %% [markdown]
# ## sort_index
#
# sort_index(axis = 0)   === for sorting according to the rows
# sort_index(axis = 1)   === for sorting according to the column

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36      58.113402       13.680000  168251
# 1   940761     Brenda       47.02      58.113402        8.978081   51063
# 2   428945        Joe       54.15      68.000000        0.980000   50155
# 3   408351      Diane       39.67      58.113402       18.300000  180294
# 4   193819   Benjamin       40.31      58.000000        4.010000  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82      89.000000        1.050000  129774
# 96  704709     Harold       32.61      77.000000        5.930000  156194
# 97  461593     Nicole       52.66      60.000000       28.530000   95673
# 98  392491    Theresa       29.60      57.000000        6.990000   51015
# 99  495141      Tammy       38.38      55.000000        2.260000   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_index(axis=0)      # rows
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36      58.113402       13.680000  168251
# 1   940761     Brenda       47.02      58.113402        8.978081   51063
# 2   428945        Joe       54.15      68.000000        0.980000   50155
# 3   408351      Diane       39.67      58.113402       18.300000  180294
# 4   193819   Benjamin       40.31      58.000000        4.010000  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82      89.000000        1.050000  129774
# 96  704709     Harold       32.61      77.000000        5.930000  156194
# 97  461593     Nicole       52.66      60.000000       28.530000   95673
# 98  392491    Theresa       29.60      57.000000        6.990000   51015
# 99  495141      Tammy       38.38      55.000000        2.260000   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.head(1)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary City
# 0  677509       Lois       36.36      58.113402           13.68  168251  NaN

# %%
df.sort_index(axis=1)   # columns
# Out:
#     Age in Company  Age in Yrs          City  Emp ID First Name  Salary  \
# 0        13.680000       36.36           NaN  677509       Lois  168251
# 1         8.978081       47.02     Stonewall  940761     Brenda   51063
# 2         0.980000       54.15  Michigantown  428945        Joe   50155
# 3        18.300000       39.67      Hydetown  408351      Diane  180294
# 4         4.010000       40.31       Fremont  193819   Benjamin  117642
# ..             ...         ...           ...     ...        ...     ...
# 95        1.050000       22.82        Biloxi  639892       Jose  129774
# 96        5.930000       32.61  Carol Stream  704709     Harold  156194
# 97       28.530000       52.66       Detroit  461593     Nicole   95673
# 98        6.990000       29.60      Mc Grath  392491    Theresa   51015
# 99        2.260000       38.38          Alma  495141      Tammy   93650
#
#     Weight in Kgs
# 0       58.113402
# 1       58.113402
# 2       68.000000
# 3       58.113402
# ...

# %% [markdown]
# # df.T == it chnages rows to columns and columns to the rows

# %%
df.T
# Out:
#                        0          1             2          3         4   \
# Emp ID             677509     940761        428945     408351    193819
# First Name           Lois     Brenda           Joe      Diane  Benjamin
# Age in Yrs          36.36      47.02         54.15      39.67     40.31
# Weight in Kgs   58.113402  58.113402          68.0  58.113402      58.0
# Age in Company      13.68   8.978081          0.98       18.3      4.01
# Salary             168251      51063         50155     180294    117642
# City                  NaN  Stonewall  Michigantown   Hydetown   Fremont
#
#                        5        6            7        8               9   ...  \
# Emp ID             499687   539712       380086   477616          162402  ...
# First Name        Patrick    Nancy        Carol  Frances           Diana  ...
# Age in Yrs          34.86    22.14        59.12    58.18           29.73  ...
# Weight in Kgs        58.0     50.0         40.0     42.0            60.0  ...
# ...

# %%
(df.T).sort_index(axis=0)
# Out:
#                        0          1             2          3         4   \
# Age in Company      13.68   8.978081          0.98       18.3      4.01
# Age in Yrs          36.36      47.02         54.15      39.67     40.31
# City                  NaN  Stonewall  Michigantown   Hydetown   Fremont
# Emp ID             677509     940761        428945     408351    193819
# First Name           Lois     Brenda           Joe      Diane  Benjamin
# Salary             168251      51063         50155     180294    117642
# Weight in Kgs   58.113402  58.113402          68.0  58.113402      58.0
#
#                        5        6            7        8               9   ...  \
# Age in Company      12.02     0.87        34.52    23.27            3.44  ...
# Age in Yrs          34.86    22.14        59.12    58.18           29.73  ...
# City            Macksburg  Atlanta  Blanchester  Delmita  Eureka Springs  ...
# Emp ID             499687   539712       380086   477616          162402  ...
# ...

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36      58.113402       13.680000  168251
# 1   940761     Brenda       47.02      58.113402        8.978081   51063
# 2   428945        Joe       54.15      68.000000        0.980000   50155
# 3   408351      Diane       39.67      58.113402       18.300000  180294
# 4   193819   Benjamin       40.31      58.000000        4.010000  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82      89.000000        1.050000  129774
# 96  704709     Harold       32.61      77.000000        5.930000  156194
# 97  461593     Nicole       52.66      60.000000       28.530000   95673
# 98  392491    Theresa       29.60      57.000000        6.990000   51015
# 99  495141      Tammy       38.38      55.000000        2.260000   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# ## set_index
#
# it is used to replaced the index

# %%
df.head(3)
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36      58.113402       13.680000  168251
# 1  940761     Brenda       47.02      58.113402        8.978081   51063
# 2  428945        Joe       54.15      68.000000        0.980000   50155
#
#            City
# 0           NaN
# 1     Stonewall
# 2  Michigantown

# %%
df1 = df.set_index('First Name')    #for replacing the index
df1
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Lois        677509       36.36      58.113402       13.680000  168251
# Brenda      940761       47.02      58.113402        8.978081   51063
# Joe         428945       54.15      68.000000        0.980000   50155
# Diane       408351       39.67      58.113402       18.300000  180294
# Benjamin    193819       40.31      58.000000        4.010000  117642
# ...            ...         ...            ...             ...     ...
# Jose        639892       22.82      89.000000        1.050000  129774
# Harold      704709       32.61      77.000000        5.930000  156194
# Nicole      461593       52.66      60.000000       28.530000   95673
# Theresa     392491       29.60      57.000000        6.990000   51015
# Tammy       495141       38.38      55.000000        2.260000   93650
#
#                     City
# First Name
# Lois                 NaN
# Brenda         Stonewall
# ...

# %%
df2 = df.set_index("Age in Company")
df2
# Out:
#                 Emp ID First Name  Age in Yrs  Weight in Kgs  Salary  \
# Age in Company
# 13.680000       677509       Lois       36.36      58.113402  168251
# 8.978081        940761     Brenda       47.02      58.113402   51063
# 0.980000        428945        Joe       54.15      68.000000   50155
# 18.300000       408351      Diane       39.67      58.113402  180294
# 4.010000        193819   Benjamin       40.31      58.000000  117642
# ...                ...        ...         ...            ...     ...
# 1.050000        639892       Jose       22.82      89.000000  129774
# 5.930000        704709     Harold       32.61      77.000000  156194
# 28.530000       461593     Nicole       52.66      60.000000   95673
# 6.990000        392491    Theresa       29.60      57.000000   51015
# 2.260000        495141      Tammy       38.38      55.000000   93650
#
#                         City
# Age in Company
# 13.680000                NaN
# 8.978081           Stonewall
# ...

# %%
df1.head(1)
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary City
# First Name
# Lois        677509       36.36      58.113402           13.68  168251  NaN

# %%
df2 = df1.set_index("Age in Company")
df2
# Out:
#                 Emp ID  Age in Yrs  Weight in Kgs  Salary          City
# Age in Company
# 13.680000       677509       36.36      58.113402  168251           NaN
# 8.978081        940761       47.02      58.113402   51063     Stonewall
# 0.980000        428945       54.15      68.000000   50155  Michigantown
# 18.300000       408351       39.67      58.113402  180294      Hydetown
# 4.010000        193819       40.31      58.000000  117642       Fremont
# ...                ...         ...            ...     ...           ...
# 1.050000        639892       22.82      89.000000  129774        Biloxi
# 5.930000        704709       32.61      77.000000  156194  Carol Stream
# 28.530000       461593       52.66      60.000000   95673       Detroit
# 6.990000        392491       29.60      57.000000   51015      Mc Grath
# 2.260000        495141       38.38      55.000000   93650          Alma
#
# [100 rows x 5 columns]

# %%
df1
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Lois        677509       36.36      58.113402       13.680000  168251
# Brenda      940761       47.02      58.113402        8.978081   51063
# Joe         428945       54.15      68.000000        0.980000   50155
# Diane       408351       39.67      58.113402       18.300000  180294
# Benjamin    193819       40.31      58.000000        4.010000  117642
# ...            ...         ...            ...             ...     ...
# Jose        639892       22.82      89.000000        1.050000  129774
# Harold      704709       32.61      77.000000        5.930000  156194
# Nicole      461593       52.66      60.000000       28.530000   95673
# Theresa     392491       29.60      57.000000        6.990000   51015
# Tammy       495141       38.38      55.000000        2.260000   93650
#
#                     City
# First Name
# Lois                 NaN
# Brenda         Stonewall
# ...

# %%
df1.sort_index(axis=0)
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Aaron       218791       48.49           56.0           20.08   54402
# Alan        247137       38.65           80.0           11.15  154810
# Amanda      227922       35.02           40.0           10.28  114257
# Amy         893212       36.14           52.0           14.17  112715
# Andrea      183071       32.08           52.0            7.28   54179
# ...            ...         ...            ...             ...     ...
# Theresa     214352       24.66           59.0            2.52  197537
# Thomas      622406       49.85           73.0           19.15   73862
# Todd        917937       25.93           74.0            1.22  163560
# Wayne       301576       21.10           87.0            0.02   92758
# William     806955       50.05           50.0           17.36   73734
#
#                     City
# First Name
# Aaron            Eckerty
# Alan           Knoxville
# ...

# %% [markdown]
# ascending = True by default and if we put the  ascending=False then it sort in decending order

# %%
df1.sort_index(axis=0, ascending=False,inplace=True)
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# William     806955       50.05           50.0           17.36   73734
# Wayne       301576       21.10           87.0            0.02   92758
# Todd        917937       25.93           74.0            1.22  163560
# Thomas      622406       49.85           73.0           19.15   73862
# Theresa     392491       29.60           57.0            6.99   51015
# ...            ...         ...            ...             ...     ...
# Andrea      183071       32.08           52.0            7.28   54179
# Amy         893212       36.14           52.0           14.17  112715
# Amanda      227922       35.02           40.0           10.28  114257
# Alan        247137       38.65           80.0           11.15  154810
# Aaron       218791       48.49           56.0           20.08   54402
#
#                     City
# First Name
# William      Mary Esther
# Wayne              Maida
# ...

# %%
data = df.set_index('First Name',inplace=True)    #for replacing the index
data

# %%
df
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Lois        677509       36.36      58.113402       13.680000  168251
# Brenda      940761       47.02      58.113402        8.978081   51063
# Joe         428945       54.15      68.000000        0.980000   50155
# Diane       408351       39.67      58.113402       18.300000  180294
# Benjamin    193819       40.31      58.000000        4.010000  117642
# ...            ...         ...            ...             ...     ...
# Jose        639892       22.82      89.000000        1.050000  129774
# Harold      704709       32.61      77.000000        5.930000  156194
# Nicole      461593       52.66      60.000000       28.530000   95673
# Theresa     392491       29.60      57.000000        6.990000   51015
# Tammy       495141       38.38      55.000000        2.260000   93650
#
#                     City
# First Name
# Lois                 NaN
# Brenda         Stonewall
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#    First Name  Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0        Lois  677509       36.36      58.113402       13.680000  168251
# 1      Brenda  940761       47.02      58.113402        8.978081   51063
# 2         Joe  428945       54.15      68.000000        0.980000   50155
# 3       Diane  408351       39.67      58.113402       18.300000  180294
# 4    Benjamin  193819       40.31      58.000000        4.010000  117642
# ..        ...     ...         ...            ...             ...     ...
# 95       Jose  639892       22.82      89.000000        1.050000  129774
# 96     Harold  704709       32.61      77.000000        5.930000  156194
# 97     Nicole  461593       52.66      60.000000       28.530000   95673
# 98    Theresa  392491       29.60      57.000000        6.990000   51015
# 99      Tammy  495141       38.38      55.000000        2.260000   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# ## reset_index

# %%
df1
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Lois        677509       36.36      58.113402       13.680000  168251
# Brenda      940761       47.02      58.113402        8.978081   51063
# Joe         428945       54.15      68.000000        0.980000   50155
# Diane       408351       39.67      58.113402       18.300000  180294
# Benjamin    193819       40.31      58.000000        4.010000  117642
# ...            ...         ...            ...             ...     ...
# Jose        639892       22.82      89.000000        1.050000  129774
# Harold      704709       32.61      77.000000        5.930000  156194
# Nicole      461593       52.66      60.000000       28.530000   95673
# Theresa     392491       29.60      57.000000        6.990000   51015
# Tammy       495141       38.38      55.000000        2.260000   93650
#
#                     City
# First Name
# Lois                 NaN
# Brenda         Stonewall
# ...

# %%
df1.reset_index()
# Out:
#    First Name  Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0        Lois  677509       36.36      58.113402       13.680000  168251
# 1      Brenda  940761       47.02      58.113402        8.978081   51063
# 2         Joe  428945       54.15      68.000000        0.980000   50155
# 3       Diane  408351       39.67      58.113402       18.300000  180294
# 4    Benjamin  193819       40.31      58.000000        4.010000  117642
# ..        ...     ...         ...            ...             ...     ...
# 95       Jose  639892       22.82      89.000000        1.050000  129774
# 96     Harold  704709       32.61      77.000000        5.930000  156194
# 97     Nicole  461593       52.66      60.000000       28.530000   95673
# 98    Theresa  392491       29.60      57.000000        6.990000   51015
# 99      Tammy  495141       38.38      55.000000        2.260000   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df1
# Out:
#             Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# First Name
# Lois        677509       36.36      58.113402       13.680000  168251
# Brenda      940761       47.02      58.113402        8.978081   51063
# Joe         428945       54.15      68.000000        0.980000   50155
# Diane       408351       39.67      58.113402       18.300000  180294
# Benjamin    193819       40.31      58.000000        4.010000  117642
# ...            ...         ...            ...             ...     ...
# Jose        639892       22.82      89.000000        1.050000  129774
# Harold      704709       32.61      77.000000        5.930000  156194
# Nicole      461593       52.66      60.000000       28.530000   95673
# Theresa     392491       29.60      57.000000        6.990000   51015
# Tammy       495141       38.38      55.000000        2.260000   93650
#
#                     City
# First Name
# Lois                 NaN
# Brenda         Stonewall
# ...

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#    First Name  Emp ID  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0        Lois  677509       36.36      58.113402       13.680000  168251
# 1      Brenda  940761       47.02      58.113402        8.978081   51063
# 2         Joe  428945       54.15      68.000000        0.980000   50155
# 3       Diane  408351       39.67      58.113402       18.300000  180294
# 4    Benjamin  193819       40.31      58.000000        4.010000  117642
# ..        ...     ...         ...            ...             ...     ...
# 95       Jose  639892       22.82      89.000000        1.050000  129774
# 96     Harold  704709       32.61      77.000000        5.930000  156194
# 97     Nicole  461593       52.66      60.000000       28.530000   95673
# 98    Theresa  392491       29.60      57.000000        6.990000   51015
# 99      Tammy  495141       38.38      55.000000        2.260000   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df

# %%
df = pd.read_csv('Emp_Records  (1).csv')
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN             NaN   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67            NaN           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0            NaN
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# ## sort_values

# %%
df.head()
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0  677509       Lois       36.36            NaN           13.68  168251
# 1  940761     Brenda       47.02            NaN             NaN   51063
# 2  428945        Joe       54.15           68.0            0.98   50155
# 3  408351      Diane       39.67            NaN           18.30  180294
# 4  193819   Benjamin       40.31           58.0            4.01  117642
#
#            City
# 0           NaN
# 1     Stonewall
# 2  Michigantown
# 3      Hydetown
# 4       Fremont

# %%
df[30:37]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 30  329752    Lillian       36.24           49.0            2.29   67251
# 31  893212        Amy       36.14           52.0           14.17  112715
# 32  621833    Gregory       23.92           64.0            1.83  169245
# 33  456747        Roy       26.24           62.0            4.93  170895
# 34  278556    Richard       24.02           81.0            0.94  122226
# 35  333476       Mary       49.69           54.0           25.62  109394
# 36  218791      Aaron       48.49           56.0           20.08   54402
#
#          City
# 30    Panacea
# 31      Kline
# 32    Bonanza
# 33    Liberty
# 34   Ohatchee
# 35  Nashville
# 36    Eckerty

# %%
df.sort_values('First Name')
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 36  218791      Aaron       48.49           56.0           20.08   54402
# 43  247137       Alan       38.65           80.0           11.15  154810
# 41  227922     Amanda       35.02           40.0           10.28  114257
# 31  893212        Amy       36.14           52.0           14.17  112715
# 66  183071     Andrea       32.08           52.0            7.28   54179
# ..     ...        ...         ...            ...             ...     ...
# 17  214352    Theresa       24.66           59.0            2.52  197537
# 19  622406     Thomas       49.85           73.0           19.15   73862
# 64  917937       Todd       25.93           74.0            1.22  163560
# 13  301576      Wayne       21.10           87.0            0.02   92758
# 78  806955    William       50.05           50.0           17.36   73734
#
#             City
# 36       Eckerty
# 43     Knoxville
# 41  Lake Charles
# 31         Kline
# ...

# %%
df.sort_values('Age in Yrs')
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 13  301576      Wayne       21.10           87.0            0.02   92758
# 49  879753     Pamela       21.30           47.0            0.13  149262
# 59  750173    Antonio       21.93           82.0            0.24  181646
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 11  153989       Jack       22.21           61.0            0.56   82965
# ..     ...        ...         ...            ...             ...     ...
# 74  528673       Paul       58.43           60.0           22.10  145235
# 7   380086      Carol       59.12           40.0           34.52   60918
# 57  515103       Anne       59.27           48.0           14.01  114426
# 24  560455    Carolyn       59.42           53.0           16.08   42005
# 14  441771     Cheryl       59.47           47.0           26.69   92220
#
#            City
# 13        Maida
# 49       Banner
# 59     Mc Calla
# 6       Atlanta
# ...

# %%
df.sort_values('Age in Yrs', ascending=False)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 14  441771     Cheryl       59.47           47.0           26.69   92220
# 24  560455    Carolyn       59.42           53.0           16.08   42005
# 57  515103       Anne       59.27           48.0           14.01  114426
# 7   380086      Carol       59.12           40.0           34.52   60918
# 74  528673       Paul       58.43           60.0           22.10  145235
# ..     ...        ...         ...            ...             ...     ...
# 11  153989       Jack       22.21           61.0            0.56   82965
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 59  750173    Antonio       21.93           82.0            0.24  181646
# 49  879753     Pamela       21.30           47.0            0.13  149262
# 13  301576      Wayne       21.10           87.0            0.02   92758
#
#            City
# 14     Quecreek
# 24  Saint Cloud
# 57   Cookeville
# 7   Blanchester
# ...
